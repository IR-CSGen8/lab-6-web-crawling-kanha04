# %%
# !pip install holoviews
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: holoviews in c:\users\kanha\appdata\roaming\python\python311\site-packages (1.18.0)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (2.0.0)
# Requirement already satisfied: numpy>=1.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (1.25.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (3.0.0)
# Requirement already satisfied: panel>=1.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (1.3.0)
# Requirement already satisfied: colorcet in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (3.0.1)
# Requirement already satisfied: packaging in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (23.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from holoviews) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->holoviews) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->holoviews) (2023.3)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (3.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (2023.10.0)
# Requirement already satisfied: markdown in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (3.5)
# Requirement already satisfied: markdown-it-py in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (0.4.0)
# Requirement already satisfied: requests in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (4.66.1)
# Requirement already satisfied: bleach in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (6.0.0)
# Requirement already satisfied: typing-extensions in c:\users\kanha\appdata\roaming\python\python311\site-packages (from panel>=1.0->holoviews) (4.8.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from colorcet->holoviews) (0.5.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (1.1.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (10.0.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (6.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: colorama in c:\users\kanha\appdata\roaming\python\python311\site-packages (from tqdm>=4.48.0->panel>=1.0->holoviews) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\kanha\appdata\roaming\python\python311\site-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\kanha\appdata\roaming\python\python311\site-packages (from linkify-it-py->panel>=1.0->holoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from requests->panel>=1.0->holoviews) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from requests->panel>=1.0->holoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from requests->panel>=1.0->holoviews) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from requests->panel>=1.0->holoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kanha\appdata\roaming\python\python311\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->panel>=1.0->holoviews) (2.1.3)

# %%
pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in c:\users\kanha\appdata\roaming\python\python311\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import requests
import pandas as pd
import holoviews as hv
import networkx as nx
from holoviews import opts
from bs4 import BeautifulSoup
from urllib.request import urljoin

# %%
sites = "https://www.google.com/" #@param {type:"string"}
depth = 3 #@param {type:"slider", min:1, max:10, step:1}
max_child = 10 #@param {type:"slider", min:1, max:100, step:1}

def crawl(sites, depth=1, current_depth=0, max_child=10):
    get_links = lambda site: pd.Series(urljoin(site, tag.get('href')) for tag in BeautifulSoup(requests.get(site).text).find_all('a')).drop_duplicates().head(max_child)
    
    sites = pd.concat([sites, pd.DataFrame([{'link': link, 'parent': site, 'depth': current_depth + 1}
                                       for site in sites[sites.depth == current_depth].link
                                       for link in get_links(site)])], 
                         ignore_index=True).drop_duplicates('link')
    
    if depth > current_depth + 1:
        return crawl(sites, depth=depth, current_depth=current_depth+1, max_child=max_child)
    else:
        return sites


result = crawl(sites=pd.DataFrame([{'link': site, 'depth': 0, 'parent': site} for site in sites.split()]), 
               max_child=max_child,
               depth=depth)

# %%
result
# Out:
#                                                   link  depth  \
# 0                              https://www.google.com/      0
# 1            https://www.google.com/imghp?hl=km&tab=wi      1
# 2         https://maps.google.com.kh/maps?hl=km&tab=wl      1
# 3                https://play.google.com/?hl=km&tab=w8      1
# 4                      https://news.google.com/?tab=wn      1
# ..                                                 ...    ...
# 528     https://www.google.com/technologies?hl=km&fg=1      3
# 529              https://www.google.com/faq?hl=km&fg=1      3
# 531  https://www.google.com/privacy/frameworks?hl=k...      3
# 534  https://accounts.google.com/ServiceLogin?passi...      3
# 541    https://www.google.com/terms/archive?hl=km&fg=1      3
#
#                                                 parent
# 0                              https://www.google.com/
# 1                              https://www.google.com/
# 2                              https://www.google.com/
# 3                              https://www.google.com/
# 4                              https://www.google.com/
# ..                                                 ...
# 528  https://www.google.com/url?q=https://policies....
# 529  https://www.google.com/url?q=https://policies....
# 531  https://www.google.com/url?q=https://policies....
# 534  https://www.google.com/url?q=https://policies....
# 541  https://www.google.com/url?q=https://policies....
#
# [260 rows x 3 columns]

# %%
# this is just the example scenarios
# from the results you can see the links "https://support.google.com/websearch", "https://play.google.com"
# it could be the all services google site

# %%
#Task : write the regular expression to get all the services of google
text_series = result['link']

google_services_pattern = r'https://[^\s]+google\.com'
google_services = []
for text in text_series:
    matches = re.findall(google_services_pattern, str(text))
    google_services.extend(matches)
for service in google_services:
    print(service)
# Out:
# https://www.google.com
# https://www.google.com
# https://maps.google.com
# https://play.google.com
# https://news.google.com
# https://mail.google.com
# https://drive.google.com
# https://calendar.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://maps.google.com
# https://play.google.com
# https://news.google.com
# https://mail.google.com
# https://drive.google.com
# https://calendar.google.com
# https://www.google.com
# https://support.google.com
# https://play.google.com
# https://policies.google.com
# https://myaccount.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://news.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/home?tab%3Dwn%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://mail.google.com/signin/usernamerecovery?continue=https://mail.google.com/mail/u/0/?tab%3Dwm&dsh=S-418803581:1698820812210433&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://mail.google.com
# https://support.google.com
# https://mail.google.com/SignUp?cc=KH&continue=https://mail.google.com/mail/u/0/?tab%3Dwm&dsh=S-418803581:1698820812210433&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://mail.google.com
# https://support.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://www.google.com.kh/history/optout?hl%3Dkm&followup=https://www.google.com
# https://accounts.google.com
# https://support.google.com
# https://www.google.com/url?q=https://myactivity.google.com
# https://www.google.com
# https://www.google.com/url?q=/safesearch%3Fhl%3Dkm%26prev%3Dhttps://www.google.com
# https://support.google.com
# https://www.google.com/url?q=https://support.google.com
# https://www.google.com/url?q=https://policies.google.com
# https://www.google.com/url?q=https://policies.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/home?tab%3Din%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://mail.google.com/signin/usernamerecovery?continue=https://mail.google.com/mail/u/0/?tab%3Dim&dsh=S-1593361527:1698820822349927&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://mail.google.com
# https://mail.google.com/SignUp?cc=KH&continue=https://mail.google.com/mail/u/0/?tab%3Dim&dsh=S-1593361527:1698820822349927&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://mail.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dio&dsh=S-1794299846:1698820823669645&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dio&dsh=S-1794299846:1698820823669645&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://www.google.com
# https://support.google.com
# https://support.google.com
# https://support.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?hl=km&passive=true&continue=http://support.google.com
# https://support.google.com
# https://support.google.com
# https://support.google.com
# https://maps.google.com
# https://www.google.com
# https://policies.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/privacy&followup=https://policies.google.com
# https://policies.google.com
# https://policies.google.com
# https://policies.google.com
# https://policies.google.com
# https://policies.google.com
# https://myaccount.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/terms?hl%3Den-US&followup=https://policies.google.com
# https://myaccount.google.com
# https://myaccount.google.com
# https://myaccount.google.com
# https://myaccount.google.com
# https://myaccount.google.com
# https://www.google.com
# https://myaccount.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://play.google.com
# https://support.google.com
# https://play.google.com
# https://play.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/home?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://news.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/signin/usernamerecovery?continue=https://news.google.com/home?tab%3Dwn%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&dsh=S1275266881:1698820838934970&ec=GAZAqgM&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://news.google.com
# https://accounts.google.com/SignUp?cc=KH&continue=https://news.google.com/home?tab%3Dwn%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&dsh=S1275266881:1698820838934970&ec=GAZAqgM&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://news.google.com
# https://news.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://news.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtVnVHZ0pWVXlnQVAB?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB?hl%3Den-US%26gl%3DUS%26ceid%3DUS:en&followup=https://news.google.com
# https://support.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=http://support.google.com
# https://support.google.com
# https://support.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=http://support.google.com
# https://support.google.com
# https://accounts.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/privacy?gl%3DKH%26hl%3Den-US&followup=https://policies.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/terms?gl%3DKH%26hl%3Den-US&followup=https://policies.google.com
# https://accounts.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com
# https://accounts.google.com/ServiceLogin?service=wise&passive=true&continue=http%3A%2F%2Fdrive.google.com
# https://accounts.google.com/ServiceLogin?service=wise&passive=true&continue=http%3A%2F%2Fdrive.google.com
# https://workspace.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/signin/usernamerecovery?continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://www.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://drive.google.com/SignUp?cc=KH&continue=https://drive.google.com/?tab%3Dwo&dsh=S-469747730:1698820814023365&emr=1&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://drive.google.com
# https://www.google.com
# https://maps.google.com
# https://play.google.com
# https://www.google.com
# https://www.google.com
# https://classroom.google.com
# https://console.cloud.google.com
# https://trends.google.com
# https://www.google.com
# https://accounts.google.com/signin/usernamerecovery?continue=https://www.google.com.kh/history/optout?hl%3Dkm&dsh=S-2013086932:1698820870572054&ec=GAZAjQI&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://www.google.com
# https://support.google.com
# https://accounts.google.com/SignUp?cc=KH&continue=https://www.google.com.kh/history/optout?hl%3Dkm&dsh=S-2013086932:1698820870572054&ec=GAZAjQI&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://www.google.com
# https://support.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://accounts.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?hl=km&passive=true&continue=http://support.google.com
# https://support.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&osid=1&continue=https://myactivity.google.com/?continue%3Dhttps://myactivity.google.com/product/search/controls?utm_source%253Dgoogle%2526utm_medium%253Dpref-page%2526hl%253Dkm&followup=https://myactivity.google.com/?continue%3Dhttps://myactivity.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?hl=en-US&continue=https://myactivity.google.com/?continue%3Dhttps://myactivity.google.com
# https://myaccount.google.com
# https://www.google.com/signin/usernamerecovery?continue=https://www.google.com/setting/search/privateresults/?hl%3Dkm&dsh=S-988954028:1698820875687181&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://www.google.com
# https://www.google.com/SignUp?cc=KH&continue=https://www.google.com/setting/search/privateresults/?hl%3Dkm&dsh=S-988954028:1698820875687181&flowEntry=ServiceLogin&flowName=WebLiteSignIn&followup=https://www.google.com
# https://www.google.com
# https://support.google.com/websearch?p=ws_settings_safesearch&hl=km&authuser=0&prev=https://www.google.com/safesearch?hl%3Dkm%26prev%3Dhttps://www.google.com
# https://www.google.com
# https://support.google.com
# https://support.google.com
# https://accounts.google.com/ServiceLogin?hl=km&passive=true&continue=http://support.google.com
# https://support.google.com
# https://support.google.com
# https://www.google.com/url?q=https://support.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?hl=km&passive=true&continue=http://support.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/privacy?hl%3Dkm%26fg%3D1&followup=https://policies.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://www.google.com
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://policies.google.com/terms?hl%3Dkm%26fg%3D1&followup=https://policies.google.com
# https://www.google.com

# %%
#Task : Visualize the services : - how many services that google have? 
# %matplotlib inline  
import matplotlib.pyplot as plt

# Plot the occurrences of Google services
unique_services = list(set(google_services))
service_counts = [google_services.count(service) for service in unique_services]

plt.figure(figsize=(100, 70))
plt.bar(unique_services, service_counts, color='skyblue')
plt.xlabel('Google Services')
plt.ylabel('Count')
plt.title('Occurrences of Google Services')
plt.xticks(rotation=45)
plt.show()
